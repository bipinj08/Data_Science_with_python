# %% [markdown]
# # Pandas DataFrame exercises

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plot
# %matplotlib inline

print(pd.__version__)
# Out:
# 1.4.4

# %% [markdown]
# # DataFrame creation
# ### Create an empty pandas DataFrame

# %%
pd.DataFrame(data= [None],
            index = [None],
            columns = [None])
# Out:
#       None
# None  None

# %% [markdown]
# # Create a marvel_df pandas DataFrame with the given marvel data

# %%
marvel_data = [
    ['Spider-Man', 'male', 1962],
    ['Captain America', 'male', 1941],
    ['Wolverine', 'male', 1974],
    ['Iron Man', 'male', 1963],
    ['Thor', 'male', 1963],
    ['Thing', 'male', 1961],
    ['Mister Fantastic', 'male', 1961],
    ['Hulk', 'male', 1962],
    ['Beast', 'male', 1963],
    ['Invisible Woman', 'female', 1961],
    ['Storm', 'female', 1975],
    ['Namor', 'male', 1939],
    ['Hawkeye', 'male', 1964],
    ['Daredevil', 'male', 1964],
    ['Doctor Strange', 'male', 1963],
    ['Hank Pym', 'male', 1962],
    ['Scarlet Witch', 'female', 1964],
    ['Wasp', 'female', 1963],
    ['Black Widow', 'female', 1964],
    ['Vision', 'male', 1968]
]

# %%
marvel_df = pd.DataFrame(data = marvel_data)
marvel_df
# Out:
#                    0       1     2
# 0         Spider-Man    male  1962
# 1    Captain America    male  1941
# 2          Wolverine    male  1974
# 3           Iron Man    male  1963
# 4               Thor    male  1963
# 5              Thing    male  1961
# 6   Mister Fantastic    male  1961
# 7               Hulk    male  1962
# 8              Beast    male  1963
# 9    Invisible Woman  female  1961
# 10             Storm  female  1975
# 11             Namor    male  1939
# 12           Hawkeye    male  1964
# 13         Daredevil    male  1964
# 14    Doctor Strange    male  1963
# 15          Hank Pym    male  1962
# 16     Scarlet Witch  female  1964
# 17              Wasp  female  1963
# 18       Black Widow  female  1964
# 19            Vision    male  1968

# %%
columns_name = ['name', 'Gender', 'first_apperence']
marvel_df.columns = columns_name
marvel_df
# Out:
#                 name  Gender  first_apperence
# 0         Spider-Man    male             1962
# 1    Captain America    male             1941
# 2          Wolverine    male             1974
# 3           Iron Man    male             1963
# 4               Thor    male             1963
# 5              Thing    male             1961
# 6   Mister Fantastic    male             1961
# 7               Hulk    male             1962
# 8              Beast    male             1963
# 9    Invisible Woman  female             1961
# 10             Storm  female             1975
# 11             Namor    male             1939
# 12           Hawkeye    male             1964
# 13         Daredevil    male             1964
# 14    Doctor Strange    male             1963
# 15          Hank Pym    male             1962
# 16     Scarlet Witch  female             1964
# 17              Wasp  female             1963
# 18       Black Widow  female             1964
# 19            Vision    male             1968

# %% [markdown]
# # Add column names to the marvel_df

# %%
col_names = ['name', 'sex', 'first_appearance']

marvel_df.columns = col_names
marvel_df
# Out:
#                 name     sex  first_appearance
# 0         Spider-Man    male              1962
# 1    Captain America    male              1941
# 2          Wolverine    male              1974
# 3           Iron Man    male              1963
# 4               Thor    male              1963
# 5              Thing    male              1961
# 6   Mister Fantastic    male              1961
# 7               Hulk    male              1962
# 8              Beast    male              1963
# 9    Invisible Woman  female              1961
# 10             Storm  female              1975
# 11             Namor    male              1939
# 12           Hawkeye    male              1964
# 13         Daredevil    male              1964
# 14    Doctor Strange    male              1963
# 15          Hank Pym    male              1962
# 16     Scarlet Witch  female              1964
# 17              Wasp  female              1963
# 18       Black Widow  female              1964
# 19            Vision    male              1968

# %% [markdown]
# # Add index names to the marvel_df (use the character name as index)

# %%
marvel_df.index = marvel_df['name']
marvel_df
# Out:
#                               name     sex  first_appearance
# name
# Spider-Man              Spider-Man    male              1962
# Captain America    Captain America    male              1941
# Wolverine                Wolverine    male              1974
# Iron Man                  Iron Man    male              1963
# Thor                          Thor    male              1963
# Thing                        Thing    male              1961
# Mister Fantastic  Mister Fantastic    male              1961
# Hulk                          Hulk    male              1962
# Beast                        Beast    male              1963
# Invisible Woman    Invisible Woman  female              1961
# Storm                        Storm  female              1975
# Namor                        Namor    male              1939
# Hawkeye                    Hawkeye    male              1964
# Daredevil                Daredevil    male              1964
# Doctor Strange      Doctor Strange    male              1963
# Hank Pym                  Hank Pym    male              1962
# Scarlet Witch        Scarlet Witch  female              1964
# Wasp                          Wasp  female              1963
# Black Widow            Black Widow  female              1964
# Vision                      Vision    male              1968

# %% [markdown]
# # Drop the name column as it's now the index

# %%
marvel_df = marvel_df.drop(['name'], axis = 1)
marvel_df
# Out:
#                      sex  first_appearance
# name
# Spider-Man          male              1962
# Captain America     male              1941
# Wolverine           male              1974
# Iron Man            male              1963
# Thor                male              1963
# Thing               male              1961
# Mister Fantastic    male              1961
# Hulk                male              1962
# Beast               male              1963
# Invisible Woman   female              1961
# Storm             female              1975
# Namor               male              1939
# Hawkeye             male              1964
# Daredevil           male              1964
# Doctor Strange      male              1963
# Hank Pym            male              1962
# Scarlet Witch     female              1964
# Wasp              female              1963
# Black Widow       female              1964
# Vision              male              1968

# %% [markdown]
# # Drop 'Namor' and 'Hank Pym' rows

# %%
marvel_df = marvel_df.drop(['Namor', 'Hank Pym'], axis = 0)
marvel_df
# Out:
#                      sex  first_appearance
# name
# Spider-Man          male              1962
# Captain America     male              1941
# Wolverine           male              1974
# Iron Man            male              1963
# Thor                male              1963
# Thing               male              1961
# Mister Fantastic    male              1961
# Hulk                male              1962
# Beast               male              1963
# Invisible Woman   female              1961
# Storm             female              1975
# Hawkeye             male              1964
# Daredevil           male              1964
# Doctor Strange      male              1963
# Scarlet Witch     female              1964
# Wasp              female              1963
# Black Widow       female              1964
# Vision              male              1968

# %% [markdown]
# # DataFrame selection, slicing and indexation
# #### Show the first 5 elements on marvel_df

# %%
marvel_df.head()
# Out:
#                   sex  first_appearance
# name
# Spider-Man       male              1962
# Captain America  male              1941
# Wolverine        male              1974
# Iron Man         male              1963
# Thor             male              1963

# %%
marvel_df[0:5]
# Out:
#                   sex  first_appearance
# name
# Spider-Man       male              1962
# Captain America  male              1941
# Wolverine        male              1974
# Iron Man         male              1963
# Thor             male              1963

# %% [markdown]
# # Show just the sex of the first 5 elements on marvel_df

# %%
#marvel_df = marvel_df[:5].sex.to_frame()
#marvel_df

# %% [markdown]
# # Show the first_appearance of all middle elements on marvel_df

# %%
marvel_df = marvel_df[1:-1].first_appearance.to_frame()
marvel_df
# Out:
#                   first_appearance
# name
# Captain America               1941
# Wolverine                     1974
# Iron Man                      1963
# Thor                          1963
# Thing                         1961
# Mister Fantastic              1961
# Hulk                          1962
# Beast                         1963
# Invisible Woman               1961
# Storm                         1975
# Hawkeye                       1964
# Daredevil                     1964
# Doctor Strange                1963
# Scarlet Witch                 1964
# Wasp                          1963
# Black Widow                   1964

# %% [markdown]
# # DataFrame manipulation and operations
#
#
#
# ### Modify the first_appearance of 'Vision' to year 1964

# %%
marvel_df.head()
marvel_df.loc['Vision', 'first_appearance'] = 1964
marvel_df
# Out:
#                   first_appearance
# name
# Captain America             1941.0
# Wolverine                   1974.0
# Iron Man                    1963.0
# Thor                        1963.0
# Thing                       1961.0
# Mister Fantastic            1961.0
# Hulk                        1962.0
# Beast                       1963.0
# Invisible Woman             1961.0
# Storm                       1975.0
# Hawkeye                     1964.0
# Daredevil                   1964.0
# Doctor Strange              1963.0
# Scarlet Witch               1964.0
# Wasp                        1963.0
# Black Widow                 1964.0
# Vision                      1964.0

# %% [markdown]
# # Add a new column to marvel_df called 'years_since' with the years since first_appearance

# %%
marvel_df['years_since'] = 2023 - marvel_df['first_appearance']
marvel_df
# Out:
#                   first_appearance  years_since
# name
# Captain America             1941.0         82.0
# Wolverine                   1974.0         49.0
# Iron Man                    1963.0         60.0
# Thor                        1963.0         60.0
# Thing                       1961.0         62.0
# Mister Fantastic            1961.0         62.0
# Hulk                        1962.0         61.0
# Beast                       1963.0         60.0
# Invisible Woman             1961.0         62.0
# Storm                       1975.0         48.0
# Hawkeye                     1964.0         59.0
# Daredevil                   1964.0         59.0
# Doctor Strange              1963.0         60.0
# Scarlet Witch               1964.0         59.0
# Wasp                        1963.0         60.0
# Black Widow                 1964.0         59.0
# Vision                      1964.0         59.0

# %% [markdown]
# # DataFrame boolean arrays (also called masks)
# ### Given the marvel_df pandas DataFrame, make a mask showing the female characters

# %%
mask = marvel_df['sex'] == 'female'
marvel_df[mask]
# Out:
#                             name     sex  first_appearance
# name
# Invisible Woman  Invisible Woman  female              1961
# Storm                      Storm  female              1975
# Scarlet Witch      Scarlet Witch  female              1964
# Wasp                        Wasp  female              1963
# Black Widow          Black Widow  female              1964

# %% [markdown]
# # Given the marvel_df pandas DataFrame, get the male characters

# %%
mask = marvel_df['sex'] == 'male'
marvel_df[mask]
# Out:
#                               name   sex  first_appearance
# name
# Spider-Man              Spider-Man  male              1962
# Captain America    Captain America  male              1941
# Wolverine                Wolverine  male              1974
# Iron Man                  Iron Man  male              1963
# Thor                          Thor  male              1963
# Thing                        Thing  male              1961
# Mister Fantastic  Mister Fantastic  male              1961
# Hulk                          Hulk  male              1962
# Beast                        Beast  male              1963
# Namor                        Namor  male              1939
# Hawkeye                    Hawkeye  male              1964
# Daredevil                Daredevil  male              1964
# Doctor Strange      Doctor Strange  male              1963
# Hank Pym                  Hank Pym  male              1962
# Vision                      Vision  male              1968

# %% [markdown]
# # Given the marvel_df pandas DataFrame, get the characters with first_appearance after 1970

# %%
mask = marvel_df['first_appearance'] > 1970
marvel_df[mask]
# Out:
#                 name     sex  first_appearance
# name
# Wolverine  Wolverine    male              1974
# Storm          Storm  female              1975

# %% [markdown]
# # Given the marvel_df pandas DataFrame, get the female characters with first_appearance after 1970

# %%
mask = (marvel_df['first_appearance'] > 1970) & (marvel_df['sex'] == 'female')
marvel_df[mask]
# Out:
#         name     sex  first_appearance
# name
# Storm  Storm  female              1975

# %% [markdown]
# # DataFrame summary statistics
#
#
# ### Show basic statistics of marvel_df

# %%
marvel_df.describe()
# Out:
#        first_appearance
# count         20.000000
# mean        1961.850000
# std            8.405982
# min         1939.000000
# 25%         1961.750000
# 50%         1963.000000
# 75%         1964.000000
# max         1975.000000

# %% [markdown]
# # Given the marvel_df pandas DataFrame, show the mean value of first_appearance

# %%
marvel_df['first_appearance'].mean()
# Out:
# 1961.85

# %% [markdown]
# # Given the marvel_df pandas DataFrame, show the min value of first_appearance

# %%
marvel_df.first_appearance.min()
# Out:
# 1939

# %% [markdown]
# # Given the marvel_df pandas DataFrame, get the characters with the min value of first_appearance

# %%
mask = marvel_df['first_appearance'] == marvel_df['first_appearance'].min()
marvel_df[mask]
# Out:
#         name   sex  first_appearance
# name
# Namor  Namor  male              1939

# %% [markdown]
# # DataFrame basic
#
# ### Plot the values of first_appearance

# %%
marvel_df.first_appearance.plot()
# Out:
# <AxesSubplot:xlabel='name'>

# %% [markdown]
# # Plot a histogram (plot.hist) with values of first_appearance

# %%
plot.hist(marvel_df.first_appearance)
# Out:
# (array([ 2.,  0.,  0.,  0.,  0.,  0., 15.,  0.,  1.,  2.]),
#  array([1939. , 1942.6, 1946.2, 1949.8, 1953.4, 1957. , 1960.6, 1964.2,
#         1967.8, 1971.4, 1975. ]),
#  <BarContainer object of 10 artists>)
